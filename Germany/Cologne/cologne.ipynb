# %% [markdown]
# # Librairies

# %%
import geopandas as gpd
import numpy as np
from tqdm import tqdm
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# # Load data

# %%
gdf = gpd.read_file('raw/traffic.php.json')

# %%
gdf.auslastung.unique()
# [utilization] > load-out - VAT - e.g. (0,1 or 2) 0 - free 1 - tensing 2 - traffic jam 16 - no display,
# presumably due to defective sensors 32 - additional note in the field Link (e.g. at large events)
# Out:
# array([ 0, 16,  1,  2], dtype=int16)

# %%
gdf.plot()
plt.axis('off')
# Out:
# (6.832351715912859, 7.111679150849827, 50.885357916782894, 51.03018458761401)

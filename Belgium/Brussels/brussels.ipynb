# %%
import pandas as pd

# %%
pd.read_json('raw/data.mobility.brussels.json')
# Out:
#                  requestDate  \
# ARL_103  2025/01/09 10:49:30
# ARL_203  2025/01/09 10:49:30
# BAI_TD1  2025/01/09 10:49:30
# BAI_TD2  2025/01/09 10:49:30
# BEL_TD4  2025/01/09 10:49:30
# ...                      ...
# TRO_TD2  2025/01/09 10:49:30
# VLE_103  2025/01/09 10:49:30
# VLE_203  2025/01/09 10:49:30
# VP_103   2025/01/09 10:49:30
# VP_203   2025/01/09 10:49:30
#
#                                                       data
# ARL_103  {'results': {'60m': {'t1': {'count': 2083, 'sp...
# ARL_203  {'results': {'60m': {'t1': {'count': 1542, 'sp...
# BAI_TD1  {'results': {'60m': {'t1': {'count': 959, 'spe...
# BAI_TD2  {'results': {'60m': {'t1': {'count': 704, 'spe...
# BEL_TD4  {'results': {'60m': {'t1': {'count': 1043, 'sp...
# ...                                                    ...
# TRO_TD2  {'results': {'60m': {'t1': {'count': 1597, 'sp...
# VLE_103  {'results': {'60m': {'t1': {'count': 761, 'spe...
# VLE_203  {'results': {'60m': {'t1': {'count': 816, 'spe...
# ...

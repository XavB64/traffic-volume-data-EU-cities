# %%
import geopandas as gpd
import matplotlib.pylab as plt
import contextily as cx

# %%
gdf = gpd.read_file('raw/244400404_fluidite-axes-routiers-nantes-metropole.geojson')

# %%
# Plot sensors
#plt.figure(figsize = (10,10), dpi = 300)

fig, ax = plt.subplots(figsize = (7,7), dpi = 200)
gdf.plot(ax=ax, color = 'r', markersize = 5, alpha = .5)
# Add context in backround
cx.add_basemap(ax, crs = gdf.crs, source=cx.providers.CartoDB.VoyagerNoLabels)

cx.add_basemap(ax, crs = gdf.crs, source=cx.providers.CartoDB.VoyagerOnlyLabels)

# Remove lat lon
plt.axis('off')
plt.axis('auto')
# Out:
# (-1.7578983306884761,
#  -1.4063511474541683,
#  47.130005278122624,
#  47.30909244468039)

# %%
gdf.cha_id.unique().size
# Out:
# 847

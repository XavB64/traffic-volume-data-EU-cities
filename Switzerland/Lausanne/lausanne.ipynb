# %% [markdown]
# # Librairies

# %%
import geopandas as gpd
import numpy as np
from tqdm import tqdm
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# # Load data

# %%
gdf = gpd.read_file('raw/Trafic-journalier-moyen/DGMR_TPR_TJM/MN95_DGMR_TPR_TJM.shp')

# %%
import contextily as cx

# Plot sensors
ax = gdf.plot(color = 'r', markersize = 20, alpha = .5, figsize = (10,10))
# Add context in backround
cx.add_basemap(ax, crs = gdf.crs, source=cx.providers.CartoDB.VoyagerNoLabels)

cx.add_basemap(ax, crs = gdf.crs, source=cx.providers.CartoDB.VoyagerOnlyLabels)

# Remove lat lon
plt.axis('off')
plt.axis('auto')
# Out:
# (2486831.9434752883, 2595755.737320007, 1102492.4319255035, 1210995.6705816325)

# %%
# Only regional roads
